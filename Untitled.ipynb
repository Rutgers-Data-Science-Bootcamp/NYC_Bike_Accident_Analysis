# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = 'C:/Users/14255/Desktop/Bootcamp/20. Final/Final_Project_by_Met_A_Four/NYC_BICYCLE_NETWORK.csv'

# %%
# Load the crypto_data.csv dataset.
file_path = "NYC_BICYCLE_NETWORK.csv"
bike_lane_df = pd.read_csv(file_path)
print(bike_lane_df.shape)
bike_lane_df.head(10)
# Out:
# (20824, 17)
#                                             the_geom  segmentid  Shape_Le_1  \
# 0  MULTILINESTRING ((-74.24992754986717 40.500876...         53  131.771990
# 1  MULTILINESTRING ((-74.24915648792326 40.498717...         57  268.689582
# 2  MULTILINESTRING ((-74.24934702119957 40.499440...         59  420.193253
# 3  MULTILINESTRING ((-74.25185153133741 40.502805...         61  238.242198
# 4  MULTILINESTRING ((-74.2513327304861 40.5022891...         64  646.293832
# 5  MULTILINESTRING ((-74.24893307025533 40.498044...        139  252.694133
# 6  MULTILINESTRING ((-74.24797739438884 40.498230...        141  274.263815
# 7  MULTILINESTRING ((-74.24701764165971 40.498418...        145  275.606456
# 8  MULTILINESTRING ((-74.24616510562565 40.498582...        157  244.477014
# 9  MULTILINESTRING ((-74.24526409179525 40.498767...        233  259.526450
#
#    boro                          street  fromstreet       tostreet onoffst  \
# 0     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 1     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 2     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 3     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 4     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 5     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 6     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 7     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 8     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
# 9     5  CONFERENCE HOUSE PARK GREENWAY  HYLAN BLVD  SWINNERTON ST     OFF
#
#   facilitycl allclasses bikedir  lanecount ft_facilit tf_facilit ft2facilit  \
# 0          I          I       2          2   Greenway   Greenway        NaN
# 1          I          I       2          2   Greenway   Greenway        NaN
# 2          I          I       2          2   Greenway   Greenway        NaN
# 3          I          I       2          2   Greenway   Greenway        NaN
# 4          I          I       2          2   Greenway   Greenway        NaN
# 5          I          I       2          2   Greenway   Greenway        NaN
# 6          I          I       2          2   Greenway   Greenway        NaN
# 7          I          I       2          2   Greenway   Greenway        NaN
# 8          I          I       2          2   Greenway   Greenway        NaN
# 9          I          I       2          2   Greenway   Greenway        NaN
#
#   tf2facilit comments
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# 5        NaN      NaN
# 6        NaN      NaN
# 7        NaN      NaN
# 8        NaN      NaN
# 9        NaN      NaN

# %%
bike_lane_df.drop_duplicates(subset = ["street"])
# Out:
#                                                 the_geom  segmentid  \
# 0      MULTILINESTRING ((-74.24992754986717 40.500876...         53
# 10     MULTILINESTRING ((-74.22765169907424 40.508199...        735
# 13     MULTILINESTRING ((-74.22124840590146 40.505101...        841
# 28     MULTILINESTRING ((-74.19697470899112 40.557563...       2416
# 45     MULTILINESTRING ((-74.16694849149822 40.602796...       4871
# ...                                                  ...        ...
# 20754  MULTILINESTRING ((-73.84227808018568 40.741245...     177286
# 20782  MULTILINESTRING ((-74.02916023126342 40.640774...      17575
# 20786  MULTILINESTRING ((-73.79512969395029 40.866381...     321550
# 20802  MULTILINESTRING ((-73.98875574891973 40.695018...     162715
# 20806  MULTILINESTRING ((-73.9623259945716 40.6299687...     115163
#
#        Shape_Le_1  boro                          street           fromstreet  \
# 0      131.771990     5  CONFERENCE HOUSE PARK GREENWAY           HYLAN BLVD
# 10     690.286899     5                      HYLAN BLVD              PAGE AV
# 13     836.449298     5          MOUNT LORETTO GREENWAY           HYLAN BLVD
# 28     440.773031     1         79 ST NORTH ACCESS RAMP              W 79 ST
# 45     271.541232     5                       ARLENE ST          LAMBERTS LA
# ...           ...   ...                             ...                  ...
# 20754   63.135302     4                 AMPHITHEATRE BR     EDERLE PROMENADE
# 20782  266.682165     3                      WAKEMAN PL          COLONIAL RD
# 20786  422.638126     2    ORCHARD BEACH BOARDWALK LINK  PARK DRIVE GREENWAY
# 20802   39.491486     3                      JOHNSON ST             ADAMS ST
# 20806   98.023448     3             AVE H PED UNDERPASS                AVE H
#
#                                  tostreet onoffst facilitycl allclasses  \
# 0                           SWINNERTON ST     OFF          I          I
# 10                             POILLON AV      ON         II         II
# 13                             HYLAN BLVD     OFF          I          I
# 28     HUDSON RIVER GREENWAY 79TH ST LINK     OFF         II     II,III
# 45                               SIGNS RD      ON         II         II
# ...                                   ...     ...        ...        ...
# 20754                         MERIDIAN RD     OFF          I          I
# 20782                            RIDGE BL     OFF          I          I
# 20786             PRCHARD BEACH BOARDWALK     OFF          L          L
# 20802                              JAY ST      ON          I      III,I
# 20806                               AVE H     OFF          L          L
#
#       bikedir  lanecount ft_facilit      tf_facilit ft2facilit tf2facilit  \
# 0           2          2   Greenway        Greenway        NaN        NaN
# 10          2          2   Standard        Standard        NaN        NaN
# 13          2          2   Greenway        Greenway        NaN        NaN
# 28          2          2   Curbside        Sharrows        NaN        NaN
# 45          2          2   Standard        Standard        NaN        NaN
# ...       ...        ...        ...             ...        ...        ...
# 20754       2          2   Greenway        Greenway        NaN        NaN
# 20782       2          2   Sidewalk        Sidewalk        NaN        NaN
# 20786       2          0        NaN             NaN        NaN        NaN
# 20802       2          2   Sharrows  Protected Path        NaN        NaN
# 20806       2          0        NaN             NaN        NaN        NaN
#
#                           comments
# 0                              NaN
# 10                             NaN
# 13                             NaN
# 28     limited access road (parks)
# 45                             NaN
# ...                            ...
# 20754                          NaN
# 20782                          NaN
# 20786                          NaN
# 20802                          NaN
# 20806                          NaN
#
# [1292 rows x 17 columns]

# %%
# Saving cleaned data
file_path = "C:/Users/14255/Desktop/Bootcamp/20. Final/Final_Project_by_Met_A_Four/NYC_BICYCLE_NETWORK_cleaned.csv"
bike_lane_df.to_csv(file_path, index=False)
