# %%
# Initial imports
import numpy as np
import pandas as pd
# import hvplot.pandas
from pathlib import Path
# import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# import Final_project_NYC_BIKE_LANE_cleaned.csv data to match accident site 
file_path = "Resources/Segment2/Final_Project_NYC_CRASH_LANE_xDATABASE.csv"
CL_df= pd.read_csv(file_path, index_col=0 )
print(CL_df.shape)
CL_df
# Out:
# (9193, 21)
#       COLLISION_ID    DATES      TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0          4271563   1/2/20  13:00:00  MANHATTAN     10003  40.714165
# 1          4268322   1/2/20  16:00:00  MANHATTAN     10012  40.725643
# 2          4268207   1/2/20  17:00:00   BROOKLYN     11221  40.693874
# 3          4268408   1/3/20   8:00:00      BRONX     10456  40.820747
# 4          4269187   1/3/20  11:00:00   BROOKLYN     11205  40.691017
# ...            ...      ...       ...        ...       ...        ...
# 9188       4571618  10/9/22   1:00:00     QUEENS     11375  40.734295
# 9189       4571590  10/9/22   6:00:00   BROOKLYN     11201  40.689840
# 9190       4571393  10/9/22  11:00:00   BROOKLYN     11201  40.702610
# 9191       4571698  10/9/22  12:00:00  MANHATTAN     10002  40.715080
# 9192       4571553  10/9/22  20:00:00   BROOKLYN     11223  40.600590
#
#       LONGITUDE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# ...

# %%
CWL_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9193 entries, 0 to 9192
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COLLISION_ID                   9193 non-null   int64
#  1   DATES                          9193 non-null   object
#  2   TIME                           9193 non-null   object
#  3   BOROUGH                        9192 non-null   object
#  4   ZIP CODE                       9193 non-null   int64
#  5   LATITUDE                       9193 non-null   float64
#  6   LONGITUDE                      9193 non-null   float64
#  7   NUMBER OF PERSONS INJURED      9193 non-null   int64
#  8   NUMBER OF PERSONS KILLED       9193 non-null   int64
#  9   NUMBER OF PEDESTRIANS INJURED  9193 non-null   int64
#  10  NUMBER OF PEDESTRIANS KILLED   9193 non-null   int64
#  11  NUMBER OF CYCLIST INJURED      9193 non-null   int64
# ...

# %%
# import Final_project_NYC_BIKE_LANE_cleaned.csv data to match accident site 
file_path = "Resources/Segment2/Final_project_NYC_WEATHER_xDATABASE.csv"
WEATHER = pd.read_csv(file_path, index_col=0 )
print(WEATHER.shape)
WEATHER.head(10)
# Out:
# (9193, 7)
#     DATES      TIME   TEMP  VISIBILITY  HUMIDITY  WIND_SPEED WEATHER_MAIN
# 0  1/2/20  13:00:00  33.94     10000.0        61        9.17        Clear
# 1  1/2/20  16:00:00  42.03     10000.0        54        9.17        Clear
# 2  1/2/20  17:00:00  44.60     10000.0        48       12.75         Rain
# 3  1/3/20   8:00:00  46.78     10000.0        60        8.05         Rain
# 4  1/3/20  11:00:00  44.92     10000.0        74        8.05         Rain
# 5  1/3/20  13:00:00  44.37     10000.0        81        9.17         Rain
# 6  1/4/20   2:00:00  47.43     10000.0        81        5.82         Rain
# 7  1/5/20   9:00:00  39.42     10000.0        57       28.86       Clouds
# 8  1/5/20  14:00:00  39.02     10000.0        53       34.45       Clouds
# 9  1/6/20  19:00:00  43.83     10000.0        53       19.69       Clouds

# %%
WEATHER.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9193 entries, 0 to 9192
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATES         9193 non-null   object
#  1   TIME          9193 non-null   object
#  2   TEMP          9193 non-null   float64
#  3   VISIBILITY    9180 non-null   float64
#  4   HUMIDITY      9193 non-null   int64
#  5   WIND_SPEED    9193 non-null   float64
#  6   WEATHER_MAIN  9193 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 574.6+ KB
