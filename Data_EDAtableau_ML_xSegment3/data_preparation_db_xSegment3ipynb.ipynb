# %%
# Initial imports
import numpy as np
import pandas as pd
import hvplot.pandas
from collections import Counter
from pathlib import Path
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
# connect to sql database 
from sqlalchemy import create_engine
import psycopg2

# %%
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Final_Project"

# %%
engine = create_engine(db_string)

# %% [markdown]
# # Read the data from SQL database and Perform Basic Data Cleaning

# %%
# import Final_project_NYC_BIKE_LANE_cleaned.csv data to match accident site 
## Get Data
ML = pd.read_sql("select * from merged_data;", engine)
print(ML.shape)
ML.head(10)
# Out:
# (9193, 28)
#    collision_id       dates     times day_of_week    month    borough  \
# 0       4271563  2020-01-02  13:00:00    Thursday  January  MANHATTAN
# 1       4268322  2020-01-02  16:00:00    Thursday  January  MANHATTAN
# 2       4268207  2020-01-02  17:00:00    Thursday  January   BROOKLYN
# 3       4268408  2020-01-03  08:00:00      Friday  January      BRONX
# 4       4269187  2020-01-03  11:00:00      Friday  January   BROOKLYN
# 5       4268760  2020-01-03  13:00:00      Friday  January      BRONX
# 6       4269539  2020-01-04  02:00:00    Saturday  January     QUEENS
# 7       4268883  2020-01-05  09:00:00      Sunday  January  MANHATTAN
# 8       4269012  2020-01-05  14:00:00      Sunday  January   BROOKLYN
# 9       4273384  2020-01-06  19:00:00      Monday  January   BROOKLYN
#
#    zip_code   latitude  longitude  number_of_persons_injured  ...  \
# 0     10003  40.714165 -74.006320                          1  ...
# 1     10012  40.725643 -73.992070                          1  ...
# 2     11221  40.693874 -73.917770                          1  ...
# 3     10456  40.820747 -73.906006                          1  ...
# 4     11205  40.691017 -73.954475                          1  ...
# 5     10456  40.831055 -73.905846                          1  ...
# 6     11412  40.709023 -73.757835                          1  ...
# 7     10003  40.732845 -73.995926                          1  ...
# 8     11236  40.649060 -73.913260                          1  ...
# 9     11201  40.684810 -73.991770                          1  ...
#
#     contributing_factor_vehicle_2                  vehicle_type_code_1  \
# 0                     Unspecified                                sedan
# 1                     Unspecified                                sedan
# 2                     Unspecified  station wagon/sport utility vehicle
# 3                     Unspecified                               e-bike
# 4                    Unsafe Speed                                sedan
# 5                     Unspecified                                  van
# 6  Driver Inattention/Distraction                                sedan
# 7                     Unspecified                                 taxi
# 8                     Unspecified                                sedan
# 9                     Unspecified  station wagon/sport utility vehicle
#
#    vehicle_type_code_2           street  temperature  visibility  humidity  \
# 0                 Bike  CHAMBERS STREET        33.94     10000.0        61
# 1                 Bike           BOWERY        42.03     10000.0        54
# 2                 Bike   CENTRAL AVENUE        44.60     10000.0        48
# 3                 Taxi   JACKSON AVENUE        46.78     10000.0        60
# 4               E-Bike   DE KALB AVENUE        44.92     10000.0        74
# 5                 Bike         3 AVENUE        44.37     10000.0        81
# 6                 Bike       104 AVENUE        47.43     10000.0        81
# 7                 Bike    EAST 9 STREET        39.42     10000.0        57
# 8                 Bike   EAST 92 STREET        39.02     10000.0        53
# 9                 Bike     SMITH STREET        43.83     10000.0        53
#
#   wind_speed weather_main bike_lane
# 0       9.17        Clear         1
# 1       9.17        Clear         1
# 2      12.75         Rain         0
# 3       8.05         Rain         0
# 4       8.05         Rain         1
# 5       9.17         Rain         0
# 6       5.82         Rain         0
# 7      28.86       Clouds         1
# 8      34.45       Clouds         1
# 9      19.69       Clouds         1
#
# [10 rows x 28 columns]

# %%
# make columns in uppercase as they are in lowercase in SQL database 
ML.columns = ML.columns.str.upper()

# %%
ML.groupby(["BIKE_LANE"]).count()
# Out:
#            COLLISION_ID  DATES  TIMES  DAY_OF_WEEK  MONTH  BOROUGH  ZIP_CODE  \
# BIKE_LANE
# 0                  5998   5998   5998         5998   5998     5998      5998
# 1                  3195   3195   3195         3195   3195     3194      3195
#
#            LATITUDE  LONGITUDE  NUMBER_OF_PERSONS_INJURED  ...  \
# BIKE_LANE                                                  ...
# 0              5998       5998                       5998  ...
# 1              3195       3195                       3195  ...
#
#            CONTRIBUTING_FACTOR_VEHICLE_1  CONTRIBUTING_FACTOR_VEHICLE_2  \
# BIKE_LANE
# 0                                   5998                           5998
# 1                                   3195                           3195
#
#            VEHICLE_TYPE_CODE_1  VEHICLE_TYPE_CODE_2  STREET  TEMPERATURE  \
# BIKE_LANE
# 0                         5998                 5998    5998         5998
# 1                         3195                 3195    3195         3195
#
#            VISIBILITY  HUMIDITY  WIND_SPEED  WEATHER_MAIN
# BIKE_LANE
# 0                5990      5998        5998          5998
# 1                3190      3195        3195          3195
#
# [2 rows x 27 columns]

# %%
ML.columns.tolist()
# Out:
# ['COLLISION_ID',
#  'DATES',
#  'TIMES',
#  'DAY_OF_WEEK',
#  'MONTH',
#  'BOROUGH',
#  'ZIP_CODE',
#  'LATITUDE',
#  'LONGITUDE',
#  'NUMBER_OF_PERSONS_INJURED',
#  'NUMBER_OF_PERSONS_KILLED',
#  'NUMBER_OF_PEDESTRIANS_INJURED',
#  'NUMBER_OF_PEDESTRIANS_KILLED',
#  'NUMBER_OF_CYCLIST_INJURED',
#  'NUMBER_OF_CYCLIST_KILLED',
#  'NUMBER_OF_MOTORIST_INJURED',
#  'NUMBER_OF_MOTORIST_KILLED',
#  'CONTRIBUTING_FACTOR_VEHICLE_1',
#  'CONTRIBUTING_FACTOR_VEHICLE_2',
#  'VEHICLE_TYPE_CODE_1',
#  'VEHICLE_TYPE_CODE_2',
#  'STREET',
#  'TEMPERATURE',
#  'VISIBILITY',
#  'HUMIDITY',
#  'WIND_SPEED',
#  'WEATHER_MAIN',
#  'BIKE_LANE']

# %%
# getting columns contains strings
df_str_columns = ML.select_dtypes(include=['object'])
for col in df_str_columns.columns:
    print(col)
# Out:
# DATES
# TIMES
# DAY_OF_WEEK
# MONTH
# BOROUGH
# CONTRIBUTING_FACTOR_VEHICLE_1
# CONTRIBUTING_FACTOR_VEHICLE_2
# VEHICLE_TYPE_CODE_1
# VEHICLE_TYPE_CODE_2
# STREET
# WEATHER_MAIN

# %%
ML["TIMES"]=ML["TIMES"].astype(str)

# %%
ML["TIMES"]= ML["TIMES"].map(lambda x: x.lstrip('2022-10-29'). rstrip(' ')).map(lambda x: x.lstrip('2022-10-29'). rstrip(' '))

# %%
ML["DATES"] =pd.to_datetime(ML["DATES"])

# %%
ML.head(10)
# Out:
#    COLLISION_ID      DATES    TIMES DAY_OF_WEEK    MONTH    BOROUGH  ZIP_CODE  \
# 0       4271563 2020-01-02  3:00:00    Thursday  January  MANHATTAN     10003
# 1       4268322 2020-01-02  6:00:00    Thursday  January  MANHATTAN     10012
# 2       4268207 2020-01-02  7:00:00    Thursday  January   BROOKLYN     11221
# 3       4268408 2020-01-03  8:00:00      Friday  January      BRONX     10456
# 4       4269187 2020-01-03   :00:00      Friday  January   BROOKLYN     11205
# 5       4268760 2020-01-03  3:00:00      Friday  January      BRONX     10456
# 6       4269539 2020-01-04   :00:00    Saturday  January     QUEENS     11412
# 7       4268883 2020-01-05   :00:00      Sunday  January  MANHATTAN     10003
# 8       4269012 2020-01-05  4:00:00      Sunday  January   BROOKLYN     11236
# 9       4273384 2020-01-06   :00:00      Monday  January   BROOKLYN     11201
#
#     LATITUDE  LONGITUDE  NUMBER_OF_PERSONS_INJURED  ...  \
# 0  40.714165 -74.006320                          1  ...
# 1  40.725643 -73.992070                          1  ...
# 2  40.693874 -73.917770                          1  ...
# 3  40.820747 -73.906006                          1  ...
# 4  40.691017 -73.954475                          1  ...
# 5  40.831055 -73.905846                          1  ...
# 6  40.709023 -73.757835                          1  ...
# 7  40.732845 -73.995926                          1  ...
# 8  40.649060 -73.913260                          1  ...
# 9  40.684810 -73.991770                          1  ...
#
#     CONTRIBUTING_FACTOR_VEHICLE_2                  VEHICLE_TYPE_CODE_1  \
# 0                     Unspecified                                sedan
# 1                     Unspecified                                sedan
# 2                     Unspecified  station wagon/sport utility vehicle
# 3                     Unspecified                               e-bike
# 4                    Unsafe Speed                                sedan
# 5                     Unspecified                                  van
# 6  Driver Inattention/Distraction                                sedan
# 7                     Unspecified                                 taxi
# 8                     Unspecified                                sedan
# 9                     Unspecified  station wagon/sport utility vehicle
#
#    VEHICLE_TYPE_CODE_2           STREET  TEMPERATURE  VISIBILITY  HUMIDITY  \
# 0                 Bike  CHAMBERS STREET        33.94     10000.0        61
# 1                 Bike           BOWERY        42.03     10000.0        54
# 2                 Bike   CENTRAL AVENUE        44.60     10000.0        48
# 3                 Taxi   JACKSON AVENUE        46.78     10000.0        60
# 4               E-Bike   DE KALB AVENUE        44.92     10000.0        74
# 5                 Bike         3 AVENUE        44.37     10000.0        81
# 6                 Bike       104 AVENUE        47.43     10000.0        81
# 7                 Bike    EAST 9 STREET        39.42     10000.0        57
# 8                 Bike   EAST 92 STREET        39.02     10000.0        53
# 9                 Bike     SMITH STREET        43.83     10000.0        53
#
#   WIND_SPEED WEATHER_MAIN BIKE_LANE
# 0       9.17        Clear         1
# 1       9.17        Clear         1
# 2      12.75         Rain         0
# 3       8.05         Rain         0
# 4       8.05         Rain         1
# 5       9.17         Rain         0
# 6       5.82         Rain         0
# 7      28.86       Clouds         1
# 8      34.45       Clouds         1
# 9      19.69       Clouds         1
#
# [10 rows x 28 columns]

# %% [markdown]
# ### Transform dattimes and floats to integer

# %%
ML["TEMPERATURE"]=ML["TEMPERATURE"].astype(int)

# %%
ML["HUMIDITY"]=ML["HUMIDITY"].astype(int)

# %%
ML["WIND_SPEED"]=ML["WIND_SPEED"].astype(int)

# %%
ML["VISIBILITY"]=ML["VISIBILITY"].astype(np.float).astype("Int64")
# Out:
# /Users/dilhumarablat/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
ML.groupby(["BIKE_LANE", "NUMBER_OF_PERSONS_KILLED"]).count()
# Out:
#                                     COLLISION_ID  DATES  TIMES  DAY_OF_WEEK  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                                 5997   5997   5997         5997
#           1                                    1      1      1            1
# 1         0                                 3194   3194   3194         3194
#           1                                    1      1      1            1
#
#                                     MONTH  BOROUGH  ZIP_CODE  LATITUDE  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                          5997     5997      5997      5997
#           1                             1        1         1         1
# 1         0                          3194     3193      3194      3194
#           1                             1        1         1         1
#
#                                     LONGITUDE  NUMBER_OF_PERSONS_INJURED  ...  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED                                        ...
# 0         0                              5997                       5997  ...
#           1                                 1                          1  ...
# 1         0                              3194                       3194  ...
#           1                                 1                          1  ...
#
#                                     CONTRIBUTING_FACTOR_VEHICLE_1  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                                                  5997
#           1                                                     1
# 1         0                                                  3194
#           1                                                     1
#
#                                     CONTRIBUTING_FACTOR_VEHICLE_2  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                                                  5997
#           1                                                     1
# 1         0                                                  3194
#           1                                                     1
#
#                                     VEHICLE_TYPE_CODE_1  VEHICLE_TYPE_CODE_2  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                                        5997                 5997
#           1                                           1                    1
# 1         0                                        3194                 3194
#           1                                           1                    1
#
#                                     STREET  TEMPERATURE  VISIBILITY  HUMIDITY  \
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                           5997         5997        5989      5997
#           1                              1            1           1         1
# 1         0                           3194         3194        3189      3194
#           1                              1            1           1         1
#
#                                     WIND_SPEED  WEATHER_MAIN
# BIKE_LANE NUMBER_OF_PERSONS_KILLED
# 0         0                               5997          5997
#           1                                  1             1
# 1         0                               3194          3194
#           1                                  1             1
#
# [4 rows x 26 columns]

# %%
ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9193 entries, 0 to 9192
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COLLISION_ID                   9193 non-null   int64
#  1   DATES                          9193 non-null   datetime64[ns]
#  2   TIMES                          9193 non-null   object
#  3   DAY_OF_WEEK                    9193 non-null   object
#  4   MONTH                          9193 non-null   object
#  5   BOROUGH                        9192 non-null   object
#  6   ZIP_CODE                       9193 non-null   int64
#  7   LATITUDE                       9193 non-null   float64
#  8   LONGITUDE                      9193 non-null   float64
#  9   NUMBER_OF_PERSONS_INJURED      9193 non-null   int64
#  10  NUMBER_OF_PERSONS_KILLED       9193 non-null   int64
#  11  NUMBER_OF_PEDESTRIANS_INJURED  9193 non-null   int64
#  12  NUMBER_OF_PEDESTRIANS_KILLED   9193 non-null   int64
#  13  NUMBER_OF_CYCLIST_INJURED      9193 non-null   int64
#  14  NUMBER_OF_CYCLIST_KILLED       9193 non-null   int64
#  15  NUMBER_OF_MOTORIST_INJURED     9193 non-null   int64
#  16  NUMBER_OF_MOTORIST_KILLED      9193 non-null   int64
#  17  CONTRIBUTING_FACTOR_VEHICLE_1  9193 non-null   object
#  18  CONTRIBUTING_FACTOR_VEHICLE_2  9193 non-null   object
#  19  VEHICLE_TYPE_CODE_1            9193 non-null   object
#  20  VEHICLE_TYPE_CODE_2            9193 non-null   object
#  21  STREET                         9193 non-null   object
#  22  TEMPERATURE                    9193 non-null   int64
#  23  VISIBILITY                     9180 non-null   Int64
#  24  HUMIDITY                       9193 non-null   int64
#  25  WIND_SPEED                     9193 non-null   int64
#  26  WEATHER_MAIN                   9193 non-null   object
#  27  BIKE_LANE                      9193 non-null   int64
# dtypes: Int64(1), datetime64[ns](1), float64(2), int64(14), object(10)
# memory usage: 2.0+ MB

# %% [markdown]
# #### import the cleaned data into SQL database as ml_data

# %%
ML.to_sql(name='ml_data', con=engine)

# %%
# read the ETLed data from SQL db
ML=pd.read_sql("select * from ml_data;", engine)

# %% [markdown]
# # EDA process to understand data

# %%
# doing some EDA here 
import seaborn as sns
sns.set_style("whitegrid")

# %%
## violinplot for BROUGHS and number of persons dies, luckily there not many, only 2
plt.figure(figsize=(8,6))

sns.boxplot(data = ML,
               y = 'NUMBER_OF_PERSONS_KILLED',
               x = 'BOROUGH')

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel("NUMBER_OF_PERSONS_KILLED", fontsize=16)
plt.xlabel("BOROUGH", fontsize=16)

plt.show()

# %%
ML1=ML.groupby(["BIKE_LANE", "BOROUGH",]).count()

# %%
ML2=ML1.reset_index()

# %%
ML2
# Out:
#    BIKE_LANE        BOROUGH  index  COLLISION_ID  DATES  TIMES  DAY_OF_WEEK  \
# 0          0          BRONX   1056          1056   1056   1056         1056
# 1          0       BROOKLYN   1737          1737   1737   1737         1737
# 2          0      MANHATTAN   1531          1531   1531   1531         1531
# 3          0         QUEENS   1603          1603   1603   1603         1603
# 4          0  STATEN ISLAND     71            71     71     71           71
# 5          1          BRONX      1             1      1      1            1
# 6          1       BROOKLYN   1936          1936   1936   1936         1936
# 7          1      MANHATTAN   1038          1038   1038   1038         1038
# 8          1         QUEENS    157           157    157    157          157
# 9          1  STATEN ISLAND     62            62     62     62           62
#
#    MONTH  ZIP_CODE  LATITUDE  ...  CONTRIBUTING_FACTOR_VEHICLE_1  \
# 0   1056      1056      1056  ...                           1056
# 1   1737      1737      1737  ...                           1737
# 2   1531      1531      1531  ...                           1531
# 3   1603      1603      1603  ...                           1603
# 4     71        71        71  ...                             71
# 5      1         1         1  ...                              1
# 6   1936      1936      1936  ...                           1936
# 7   1038      1038      1038  ...                           1038
# 8    157       157       157  ...                            157
# 9     62        62        62  ...                             62
#
#    CONTRIBUTING_FACTOR_VEHICLE_2  VEHICLE_TYPE_CODE_1  VEHICLE_TYPE_CODE_2  \
# 0                           1056                 1056                 1056
# 1                           1737                 1737                 1737
# 2                           1531                 1531                 1531
# 3                           1603                 1603                 1603
# 4                             71                   71                   71
# 5                              1                    1                    1
# 6                           1936                 1936                 1936
# 7                           1038                 1038                 1038
# 8                            157                  157                  157
# 9                             62                   62                   62
#
#    STREET  TEMPERATURE  VISIBILITY  HUMIDITY  WIND_SPEED  WEATHER_MAIN
# 0    1056         1056        1054      1056        1056          1056
# 1    1737         1737        1735      1737        1737          1737
# 2    1531         1531        1530      1531        1531          1531
# 3    1603         1603        1600      1603        1603          1603
# 4      71           71          71        71          71            71
# 5       1            1           1         1           1             1
# 6    1936         1936        1932      1936        1936          1936
# 7    1038         1038        1037      1038        1038          1038
# 8     157          157         157       157         157           157
# 9      62           62          62        62          62            62
#
# [10 rows x 29 columns]

# %%
## violinplot for BOROUGHS and accident distribution
plt.figure(figsize=(10,6))
ML2_sorted = ML2.sort_values('COLLISION_ID')
sns.barplot(data = ML2_sorted,
               y = 'COLLISION_ID',
               x = 'BOROUGH',
               hue="BIKE_LANE")

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of Acccidents', fontsize=16)
plt.xlabel('BOROUGH', fontsize=16)

plt.show()

# %%
ML3=ML.groupby(["MONTH", "BIKE_LANE"]).count()
ML3=ML3.reset_index()

# %%
plt.figure(figsize=(14,8))
ML3_sorted = ML3.sort_values('COLLISION_ID')
sns.barplot(data = ML3_sorted,
               y = 'COLLISION_ID',
               x = 'MONTH',
               hue="BIKE_LANE")

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of Acccidents', fontsize=16)
plt.xlabel('MONTH', fontsize=16)

plt.show()

# %%
ML4=ML.groupby(["TIMES", "BIKE_LANE"]).count()
ML4=ML4.reset_index()

# %%
plt.figure(figsize=(16,8))
ML4_sorted = ML4.sort_values('COLLISION_ID')
sns.barplot(data = ML4_sorted,
               y = 'COLLISION_ID',
               x = 'TIMES',
               hue="BIKE_LANE")

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of Acccidents', fontsize=16)
plt.xlabel('TIMES', fontsize=16)
plt.xticks(rotation = 45)

plt.show()

# %%
ML5=ML.groupby(["DAY_OF_WEEK", "BIKE_LANE"]).count()
ML5=ML5.reset_index()

# %%
plt.figure(figsize=(16,8))
ML5_sorted = ML5.sort_values('COLLISION_ID')
sns.barplot(data = ML5_sorted,
               y = 'COLLISION_ID',
               x = 'DAY_OF_WEEK',
               hue="BIKE_LANE")

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of Acccidents', fontsize=16)
plt.xlabel('DAY_OF_WEEK', fontsize=16)
plt.xticks(rotation = 45)

plt.show()

# %%
ML6=ML.groupby(["WEATHER_MAIN", "BIKE_LANE"]).count()
ML6=ML6.reset_index()

# %%
plt.figure(figsize=(16,8))
ML6_sorted = ML6.sort_values('COLLISION_ID')
sns.barplot(data = ML6_sorted,
               y = 'COLLISION_ID',
               x = 'WEATHER_MAIN',
               hue="BIKE_LANE")

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.ylabel('Number of Acccidents', fontsize=16)
plt.xlabel('WEATHER_MAIN', fontsize=16)
plt.xticks(rotation = 45)

plt.show()
