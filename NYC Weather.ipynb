# %%
import requests
from config import weather_api_key
import time 
from datetime import datetime
import pandas as pd

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + "New%20York"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39704a67a8b5743d76123184d4d303ac&q=New%20York

# %%
url2 = "https://history.openweathermap.org/data/2.5/history/city?lat=40.7143&lon=-74.006&appid=" + weather_api_key

# %%
city_url2 = url2 + "&q=" + "New%20York"
print(city_url2)
# Out:
# https://history.openweathermap.org/data/2.5/history/city?lat=40.7143&lon=-74.006&appid=39704a67a8b5743d76123184d4d303ac&q=New%20York

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.text
# Out:
# '{"coord":{"lon":-74.006,"lat":40.7143},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":50.11,"feels_like":47.17,"temp_min":44.35,"temp_max":52.97,"pressure":1011,"humidity":50},"visibility":10000,"wind":{"speed":10.36,"deg":250},"clouds":{"all":0},"dt":1666220904,"sys":{"type":2,"id":2039034,"country":"US","sunrise":1666177880,"sunset":1666217417},"timezone":-14400,"id":5128581,"name":"New York","cod":200}'

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 50.11,
#   'feels_like': 47.17,
#   'temp_min': 44.35,
#   'temp_max': 52.97,
#   'pressure': 1011,
#   'humidity': 50},
#  'visibility': 10000,
#  'wind': {'speed': 10.36, 'deg': 250},
#  'clouds': {'all': 0},
#  'dt': 1666220904,
#  'sys': {'type': 2,
#   'id': 2039034,
#   'country': 'US',
#   'sunrise': 1666177880,
#   'sunset': 1666217417},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
df = pd.read_csv("resources/NYC_Crash_Cyclist_Clean_2020_2022.csv")

# %%
df
# Out:
#       COLLISION_ID  index  CRASH DATE CRASH TIME    BOROUGH  ZIP CODE  \
# 0          4271563  13297  2020-01-02   13:30:00  MANHATTAN     10003
# 1          4268322  13344  2020-01-02   16:00:00  MANHATTAN     10012
# 2          4268207  13347  2020-01-02   17:35:00   BROOKLYN     11221
# 3          4268408  13304  2020-01-03   08:20:00      BRONX     10456
# 4          4269187  13349  2020-01-03   11:35:00   BROOKLYN     11205
# ...            ...    ...         ...        ...        ...       ...
# 9188       4571618  13966  2022-10-09   01:11:00     QUEENS     11375
# 9189       4571590  13971  2022-10-09   06:35:00   BROOKLYN     11201
# 9190       4571393  13969  2022-10-09   11:50:00   BROOKLYN     11201
# 9191       4571698  13972  2022-10-09   12:10:00  MANHATTAN     10002
# 9192       4571553  13974  2022-10-09   20:35:00   BROOKLYN     11223
#
#        LATITUDE  LONGITUDE                 LOCATION  \
# 0     40.714165 -74.006320   (40.714165, -74.00632)
# ...

# %%
df = df.drop_duplicates(subset=['CRASH DATE'])
df.head()
# Out:
#    COLLISION_ID  index  CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0       4271563  13297  2020-01-02   13:30:00  MANHATTAN     10003  40.714165
# 3       4268408  13304  2020-01-03   08:20:00      BRONX     10456  40.820747
# 6       4269539  13255  2020-01-04   02:42:00     QUEENS     11412  40.709023
# 7       4268883  13288  2020-01-05   09:25:00  MANHATTAN     10003  40.732845
# 9       4273384  13268  2020-01-06   19:00:00   BROOKLYN     11201  40.684810
#
#    LONGITUDE                 LOCATION                    ON STREET NAME  ...  \
# 0 -74.006320   (40.714165, -74.00632)  CHAMBERS STREET                   ...
# 3 -73.906006  (40.820747, -73.906006)  JACKSON AVENUE                    ...
# 6 -73.757835  (40.709023, -73.757835)  104 AVENUE                        ...
# 7 -73.995926  (40.732845, -73.995926)  EAST 9 STREET                     ...
# 9 -73.991770    (40.68481, -73.99177)  SMITH STREET                      ...
#
# ...

# %%
# nyc_weather = pd.DataFrame

# %%
print(df.shape)
# Out:
# (1004, 22)
